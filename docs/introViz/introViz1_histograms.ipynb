# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravindh4404/DATA601UCal/blob/main/docs/introViz/introViz1_histograms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center">
#   <img src="https://raw.githubusercontent.com/tbonne/peds/main/images/Flight-delay.jpg" width="500" alt="colab">
# </p>

# %% [markdown]
# ***

# %% [markdown]
# ## <font color='darkorange'>Summary statistics and histograms</font>

# %% [markdown]
# In this exercise we will look at how to describe a variable of interest using some statistical measures. We will also learn how to plot and interpret a histogram.

# %% [markdown]
# For plotting there are many options in python. For the most part, we'll use **seaborn** for this class. It is a high level plotting library that will make it easy to plot your data in many different ways!

# %%
#Import python packages
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np

# %% [markdown]
# We'll explore different ways to summarize and visualize data using the flights data we used last class.
#
# Load that in and let's get started!

# %% [markdown]
# <p align="left">
#   <img src="https://raw.githubusercontent.com/tbonne/peds/main/images/take_action.jpg" width="100" alt="colab">
# </p>

# %%
#load in the nyc data
df_flights = pd.read_csv('/content/drive/MyDrive/dataDSI/nyc_flight_data.csv')

#take a look
df_flights
# Out:
#       Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0              1  2013      1    1     517.0             515        2.0
# 1              2  2013      1    1     533.0             529        4.0
# 2              3  2013      1    1     542.0             540        2.0
# 3              4  2013      1    1     544.0             545       -1.0
# 4              5  2013      1    1     554.0             600       -6.0
# ...          ...   ...    ...  ...       ...             ...        ...
# 3609        3610  2013      1    4       NaN            1830        NaN
# 3610        3611  2013      1    4       NaN             920        NaN
# 3611        3612  2013      1    4       NaN            1245        NaN
# 3612        3613  2013      1    4       NaN            1430        NaN
# 3613        3614  2013      1    4       NaN            1530        NaN
#
#       arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0        830.0             819       11.0      UA    1545  N14228    EWR  IAH
# 1        850.0             830       20.0      UA    1714  N24211    LGA  IAH
# 2        923.0             850       33.0      AA    1141  N619AA    JFK  MIA
# 3       1004.0            1022      -18.0      B6     725  N804JB    JFK  BQN
# 4        812.0             837      -25.0      DL     461  N668DN    LGA  ATL
# ...        ...             ...        ...     ...     ...     ...    ...  ...
# 3609       NaN            2044        NaN      9E    3716     NaN    EWR  DTW
# 3610       NaN            1245        NaN      AA     721  N541AA    LGA  DFW
# 3611       NaN            1550        NaN      AA     745  N3BGAA    LGA  DFW
# 3612       NaN            1735        NaN      AA     883  N200AA    EWR  DFW
# 3613       NaN            1725        NaN      AA    2223  N569AA    LGA  STL
#
#       air_time  distance  hour  minute            time_hour
# 0        227.0      1400     5      15  2013-01-01 05:00:00
# 1        227.0      1416     5      29  2013-01-01 05:00:00
# 2        160.0      1089     5      40  2013-01-01 05:00:00
# 3        183.0      1576     5      45  2013-01-01 05:00:00
# 4        116.0       762     6       0  2013-01-01 06:00:00
# ...        ...       ...   ...     ...                  ...
# 3609       NaN       488    18      30  2013-01-04 18:00:00
# 3610       NaN      1389     9      20  2013-01-04 09:00:00
# 3611       NaN      1389    12      45  2013-01-04 12:00:00
# 3612       NaN      1372    14      30  2013-01-04 14:00:00
# 3613       NaN       888    15      30  2013-01-04 15:00:00
#
# [3614 rows x 20 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# What kinds of variables are we dealing with?

# %%
?

# %% [markdown]
# For numeric variables we can describe their distribution.

# %%
#get the mean
delay_mean = df_flights['arr_delay'].mean()

#geth the mode
delay_mode = df_flights['arr_delay'].mode()

#get the median
delay_median = df_flights['arr_delay'].median()

#get the variance
delay_std = df_flights['arr_delay'].std()

print("the mean arrival delay is: ", delay_mean)
print("the most common arrival delay is: ", delay_mode)
print("the middle most arrival delay is: ", delay_median)
print("the standard deviation of arrival delays is: ", delay_std)
# Out:
# the mean arrival delay is:  7.204093075413513
# the most common arrival delay is:  0   -9.0
# Name: arr_delay, dtype: float64
# the middle most arrival delay is:  0.0
# the standard deviation of arrival delays is:  40.1143465868095

# %% [markdown]
# Let's make this a little more visual and plot a histogram.
# > Here we will use the histogram to visualize what delay times are most common and how spread out they are.

# %%
sns.displot(df_flights, x='arr_delay')

# %% [markdown]
# <p align="left">
#   <img src="https://raw.githubusercontent.com/tbonne/peds/main/images/take_action.jpg" width="100" alt="colab">
# </p>

# %% [markdown]
#
# Try that again but this time try playing with the bin size. How does the width of the bins we break the data into impact the histogram? Try going very big and very small. And feel free to share your results on Slack!

# %%
sns.displot(df_flights, x='arr_delay', binwidth=50) #E.g., 100

# %% [markdown]
# Let's now add in the measures of central tendencies and see how they match up on the histogram. Here we use the **plt.axvline()** method to add some vertical lines.

# %%
sns.displot(df_flights,x='arr_delay', binwidth=10)
plt.axvline(delay_mean, color="red")
plt.axvline(delay_mode[0], color="purple")
plt.axvline(delay_median, color="pink")

# %% [markdown]
# It's a little hard to see the difference, let's set focus in on a particular range of the x-axis using the **plt.xlim()** method.

# %%
sns.displot(df_flights,x='arr_delay', binwidth=10)
plt.xlim(-100,100)
plt.axvline(delay_mean, color="red")
plt.axvline(delay_mode[0], color="purple")
plt.axvline(delay_median, color="pink")

# %% [markdown]
# <p align="left">
#   <img src="https://raw.githubusercontent.com/tbonne/peds/main/images/take_action.jpg" width="100" alt="colab">
# </p>

# %% [markdown]
#
# Try this again but this time look at departure time as the variable of interest.

# %%
#get the mean
dep_mean = df_flights['dep_time'].mean()

#geth the mode
dep_mode = df_flights['dep_time'].mode()

#get the median
dep_median = df_flights['dep_time'].median()

#get the standard deviation
dep_std = df_flights['dep_time'].std()

print("the mean departure time is: ", dep_mean)
print("the most common departure time is: ", dep_mode)
print("the middle most departure time is: ", dep_median)
print("the standard deviation of departure times is: ", dep_std)
# Out:
# the mean departure time is:  1360.3469046291132
# the most common departure time is:  0    600.0
# Name: dep_time, dtype: float64
# the middle most departure time is:  1423.0
# the standard deviation of departure times is:  481.8220104738129

# %% [markdown]
# Create a histogram

# %%
sns.displot(df_flights['dep_time'], binwidth=50)
plt.axvline(dep_mean, color="red")
plt.axvline(dep_mode[0], color="blue")
plt.axvline(dep_median, color="green")

# %% [markdown]
# ### <font color='darkorange'>Measures of dispersion</font>

# %%
#get standard deviation for arrival delay
delay_sd = df_flights['arr_delay'].std()

#get standard deviation for departure times
dep_sd = df_flights['dep_time'].std()

print("standard deviation of arrival delays = ", delay_sd)
print("standard deviation of departure times = ", dep_sd)
# Out:
# standard deviation of arrival delays =  40.1143465868095
# standard deviation of departure times =  481.8220104738129

# %% [markdown]
# <p align="left">
#   <img src="https://raw.githubusercontent.com/tbonne/peds/main/images/take_action.jpg" width="100" alt="colab">
# </p>

# %% [markdown]
#
# Similarly we can find the min and max of the variables

# %%
#get the min and max of delay times
delay_min = df_flights['arr_delay'].min()
delay_max = df_flights['arr_delay'].max()

#get the min and max of departure times
time_min = df_flights['dep_time'].min()
time_max = df_flights['dep_time'].max()

#print out the values
print("min arrival delays = ", delay_min)
print("max arrival delays = ", delay_max)
print("min arrival delays = ", time_min)
print("min arrival delays = ", time_max)
# Out:
# min arrival delays =  -70.0
# max arrival delays =  851.0
# min arrival delays =  25.0
# min arrival delays =  2358.0

# %% [markdown]
# ### <font color='darkorange'>(BONUS QUESTION)</font>
#
# Find the variable(s) with the highest and lowest standard deviations and plot them in a histogram.

# %%
#estimate and sort standard deviation of all the columns
df_std = df_flights[['dep_time', 'sched_dep_time',       'dep_delay',    'arr_time',     'sched_arr_time',       'arr_delay', 'air_time',        'distance']].std().sort_values(ascending=False)
df_std
# Out:
# distance          719.806780
# arr_time          519.602991
# sched_arr_time    498.762866
# dep_time          481.822010
# sched_dep_time    468.329653
# air_time           91.375157
# arr_delay          40.114347
# dep_delay          35.863717
# dtype: float64

# %%
#estimate and sort standard deviation of all the columns
df_std = df_flights.std(numeric_only=True).sort_values(ascending=False)
df_std
# Out:
# flight            1.642781e+03
# Unnamed: 0        1.043416e+03
# distance          7.198068e+02
# arr_time          5.196030e+02
# sched_arr_time    4.987629e+02
# dep_time          4.818220e+02
# sched_dep_time    4.683297e+02
# air_time          9.137516e+01
# arr_delay         4.011435e+01
# dep_delay         3.586372e+01
# minute            1.920589e+01
# hour              4.673016e+00
# day               1.105431e+00
# year              2.274051e-13
# month             1.110377e-16
# dtype: float64

# %%
sns.displot(df_std, binwidth=50)
plt.axvline(df_std.min(), color="red")
plt.axvline(df_std.max(), color="yellow")

# %% [markdown]
# What is going on with the variables identified as having the lowest standard deviation? What does this tell you about the data?

# %% [markdown]
# Finally can you create a histogram of air speeds?

# %%
df_flights["speed"] = df_flights['distance']/df_flights['air_time']

# %%
df_flights
# Out:
#       Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0              1  2013      1    1     517.0             515        2.0
# 1              2  2013      1    1     533.0             529        4.0
# 2              3  2013      1    1     542.0             540        2.0
# 3              4  2013      1    1     544.0             545       -1.0
# 4              5  2013      1    1     554.0             600       -6.0
# ...          ...   ...    ...  ...       ...             ...        ...
# 3609        3610  2013      1    4       NaN            1830        NaN
# 3610        3611  2013      1    4       NaN             920        NaN
# 3611        3612  2013      1    4       NaN            1245        NaN
# 3612        3613  2013      1    4       NaN            1430        NaN
# 3613        3614  2013      1    4       NaN            1530        NaN
#
#       arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# 0        830.0             819       11.0  ...   1545   N14228    EWR  IAH
# 1        850.0             830       20.0  ...   1714   N24211    LGA  IAH
# 2        923.0             850       33.0  ...   1141   N619AA    JFK  MIA
# 3       1004.0            1022      -18.0  ...    725   N804JB    JFK  BQN
# 4        812.0             837      -25.0  ...    461   N668DN    LGA  ATL
# ...        ...             ...        ...  ...    ...      ...    ...  ...
# 3609       NaN            2044        NaN  ...   3716      NaN    EWR  DTW
# 3610       NaN            1245        NaN  ...    721   N541AA    LGA  DFW
# 3611       NaN            1550        NaN  ...    745   N3BGAA    LGA  DFW
# 3612       NaN            1735        NaN  ...    883   N200AA    EWR  DFW
# 3613       NaN            1725        NaN  ...   2223   N569AA    LGA  STL
#
#      air_time  distance  hour  minute            time_hour     speed
# 0       227.0      1400     5      15  2013-01-01 05:00:00  6.167401
# 1       227.0      1416     5      29  2013-01-01 05:00:00  6.237885
# 2       160.0      1089     5      40  2013-01-01 05:00:00  6.806250
# 3       183.0      1576     5      45  2013-01-01 05:00:00  8.612022
# 4       116.0       762     6       0  2013-01-01 06:00:00  6.568966
# ...       ...       ...   ...     ...                  ...       ...
# 3609      NaN       488    18      30  2013-01-04 18:00:00       NaN
# 3610      NaN      1389     9      20  2013-01-04 09:00:00       NaN
# 3611      NaN      1389    12      45  2013-01-04 12:00:00       NaN
# 3612      NaN      1372    14      30  2013-01-04 14:00:00       NaN
# 3613      NaN       888    15      30  2013-01-04 15:00:00       NaN
#
# [3614 rows x 21 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_flights['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_flights['day'].plot(kind='hist', bins=20, title='day')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_flights['dep_time'].plot(kind='hist', bins=20, title='dep_time')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_flights['sched_dep_time'].plot(kind='hist', bins=20, title='sched_dep_time')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df_flights.groupby('origin').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_flights.plot(kind='scatter', x='Unnamed: 0', y='day', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_flights.plot(kind='scatter', x='day', y='dep_time', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_flights.plot(kind='scatter', x='dep_time', y='sched_dep_time', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_flights.plot(kind='scatter', x='sched_dep_time', y='dep_delay', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['dep_delay']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df_flights.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('origin')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='origin', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('dep_delay')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['arr_delay']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df_flights.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('origin')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='origin', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('arr_delay')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['flight']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df_flights.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('origin')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='origin', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('flight')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['distance']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df_flights.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('origin')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='origin', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('distance')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_flights['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df_flights['day'].plot(kind='line', figsize=(8, 4), title='day')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df_flights['dep_time'].plot(kind='line', figsize=(8, 4), title='dep_time')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df_flights['sched_dep_time'].plot(kind='line', figsize=(8, 4), title='sched_dep_time')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df_flights['origin'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df_flights, x='Unnamed: 0', y='origin', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df_flights['origin'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df_flights, x='day', y='origin', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df_flights['origin'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df_flights, x='dep_time', y='origin', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df_flights['origin'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df_flights, x='sched_dep_time', y='origin', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# Warning: Total number of columns (21) exceeds max_columns (20) limiting to first (20) columns.

# %%
df_flights.sort_values(by='speed', ascending=False)
# Out:
#       Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 178          179  2013      1    1     909.0             810       59.0
# 28            29  2013      1    1     615.0             615        0.0
# 127          128  2013      1    1     820.0             820        0.0
# 1776        1777  2013      1    2    2354.0            2359       -5.0
# 593          594  2013      1    1    1716.0            1545       91.0
# ...          ...   ...    ...  ...       ...             ...        ...
# 3609        3610  2013      1    4       NaN            1830        NaN
# 3610        3611  2013      1    4       NaN             920        NaN
# 3611        3612  2013      1    4       NaN            1245        NaN
# 3612        3613  2013      1    4       NaN            1430        NaN
# 3613        3614  2013      1    4       NaN            1530        NaN
#
#       arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# 178     1331.0            1315       16.0  ...    655   N5EXAA    JFK  STT
# 28      1039.0            1100      -21.0  ...    709   N794JB    JFK  SJU
# 127     1249.0            1329      -40.0  ...    301   N900PC    JFK  SJU
# 1776     413.0             437      -24.0  ...    727   N789JB    JFK  BQN
# 593     2140.0            2039       61.0  ...    703   N651JB    JFK  SJU
# ...        ...             ...        ...  ...    ...      ...    ...  ...
# 3609       NaN            2044        NaN  ...   3716      NaN    EWR  DTW
# 3610       NaN            1245        NaN  ...    721   N541AA    LGA  DFW
# 3611       NaN            1550        NaN  ...    745   N3BGAA    LGA  DFW
# 3612       NaN            1735        NaN  ...    883   N200AA    EWR  DFW
# 3613       NaN            1725        NaN  ...   2223   N569AA    LGA  STL
#
#      air_time  distance  hour  minute            time_hour     speed
# 178     184.0      1623     8      10  2013-01-01 08:00:00  8.820652
# 28      182.0      1598     6      15  2013-01-01 06:00:00  8.780220
# 127     182.0      1598     8      20  2013-01-01 08:00:00  8.780220
# 1776    180.0      1576    23      59  2013-01-02 23:00:00  8.755556
# 593     183.0      1598    15      45  2013-01-01 15:00:00  8.732240
# ...       ...       ...   ...     ...                  ...       ...
# 3609      NaN       488    18      30  2013-01-04 18:00:00       NaN
# 3610      NaN      1389     9      20  2013-01-04 09:00:00       NaN
# 3611      NaN      1389    12      45  2013-01-04 12:00:00       NaN
# 3612      NaN      1372    14      30  2013-01-04 14:00:00       NaN
# 3613      NaN       888    15      30  2013-01-04 15:00:00       NaN
#
# [3614 rows x 21 columns]

# %%
df_flights.groupby('carrier').speed.mean().sort_values(ascending=False)
# Out:
# carrier
# HA    7.814802
# VX    7.479769
# AS    7.243138
# F9    7.092209
# UA    6.665590
# AA    6.522017
# DL    6.509856
# B6    6.426155
# FL    5.959070
# WN    5.816925
# US    5.702300
# MQ    5.524847
# EV    5.327594
# 9E    5.176311
# YV    4.721645
# Name: speed, dtype: float64

# %%
sns.displot(df_flights, x = 'speed')

# %%
sns.displot(df_flights, x = 'speed')

# %% [markdown]
# What are the unit of the x-axis in this histogram?
#
#
# Finally, can you identify the speediest airline carrier?

# %%
maxspeed = df_flights['speed'].max()
maxspeed
# Out:
# 8.820652173913043

# %%
df_flights.speed.sort_values(ascending=False)
# Out:
# 178     8.820652
# 28      8.780220
# 127     8.780220
# 1776    8.755556
# 593     8.732240
#           ...
# 3609         NaN
# 3610         NaN
# 3611         NaN
# 3612         NaN
# 3613         NaN
# Name: speed, Length: 3614, dtype: float64

# %% [markdown]
# ### <font color='darkorange'>Further reading</font>

# %% [markdown]
# > If you would like the notebook without missing code check out the [full code](https://colab.research.google.com/github/tbonne/peds/blob/main/docs/fullNotebooks/full_introViz1_histograms.ipynb) version.
